# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#pandas #numpy #matplotlib #seaborn

# %%
dataset = pd.read_csv('covid19_patient_data.csv')

dataset.head()

#no transformation required. All are numerical data i.e., encoded
#read csv file
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
corrmat = dataset.corr()
f, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(corrmat, vmax=.8, square=True, annot=True, fmt='.2f')
plt.show()

#heatmap
#Correlation Matrix

# %%
dataset.Target.unique()
x=dataset[['Fever','ThroatInfections','BreathingIssue']]

y=dataset['Target']

#defining input variables x and y

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

#training and testing data spliting

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier
#classifier (to get parameters)
#max_depth criterion max_features
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
classifier.fit(x_train, y_train)

#model can be ready to classify using fit
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
score = classifier.score(x_test, y_test)
print(score)

#to obtain score value for evaluation of classifier (accuracy)
# Out:
# 0.5193877551020408

# %%
classifier.n_features_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-6c86419293cd> in <module>
# ----> 1 classifier.n_features_
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'n_features_'

# %%
classifier.feature_importances_
# Out:
# array([0.07373387, 0.09513389, 0.08170673, 0.06622366, 0.08854667,
#        0.11076449, 0.09507967, 0.08158243, 0.08695739, 0.0849197 ,
#        0.13535149])

# %%
import sklearn.tree as tree
tree.export_graphviz(classifier, out_file='tree.dot', feature_names=x.columns)

#for obtaining the tree
